# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# pyplot maintains an internal state in which you build the vis step by step
#
# can save it with savefig() or display with show()

# %% [markdown]
# # Line charts

# %%
years = range(1950, 2011, 10)
gdp = [300.2, 543.3, 1075.9, 2863.5, 5979.6, 10289.7, 14958.3]

plt.plot(years, gdp, color = 'green', marker = 'o', linestyle = 'solid')
plt.title("Nominal GDP")
plt.ylabel('Billions of $')
# plt.show()

# %% [markdown]
# # Bar charts

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# %% [markdown]
# plot in order of some arbitrary index

# %% [markdown]
# bars are by default 0.8 width, add 0.1 to center

# %%
xs = [i+0.1 for i,_ in enumerate(movies)]

# %% [markdown]
# plot bars with x-coords, heights

# %%
plt.bar(xs, num_oscars)
# Out:
# <Container object of 5 artists>

# %%
plt.bar(xs, num_oscars)
plt.ylabel("# of Academy Awards")
plt.title("My favorite movies")
plt.xticks([i+0.5 for i,_ in enumerate(movies)], movies) # at specific tick, label with a movie
# Out:
# ([<matplotlib.axis.XTick at 0xb037978>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]
decile = lambda grade: grade // 10 * 10

# %%
from collections import Counter
histogram = Counter(decile(grade) for grade in grades)
histogram
# Out:
# Counter({80: 4, 70: 3, 0: 2, 90: 2, 100: 1, 60: 1})

# %%
plt.bar(histogram.keys(), histogram.values())
# Out:
# <Container object of 6 artists>

# %%
plt.bar([x-4 for x in histogram.keys()], # shift x-position 8 units to right of default
       histogram.values(), # give each bar its correct height
       8) # buckets are size 10 so we make bars size 8 (1 unit on each side of breathing room)

plt.axis([-5, 105, 0, 5]) # fit all axes in one command by specifying [xmin, xmax, ymin, ymax]

plt.xticks([10 * i for i in range(11)]) # labels at 0, 10, ... 100

plt.xlabel('Decile')
plt.ylabel('# of Students')
plt.title("Distribution of Exam 1 Grades")

# %%
mentions = [500, 505]
years = [2013, 2014]

plt.bar([2012.6, 2013.6], mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")

# %%
plt.bar([2012.6, 2013.6], mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")

# if you don't do this, matplotlib will label the x-axis 0, 1
# and then add a +2.013e3 off in the corner (bad matplotlib!)
plt.ticklabel_format(useOffset=False)

plt.axis([2012.5,2014.5,499,506])
plt.title("Look at the 'Huge' Increase!")

# %%
# always start y-axis at 0 for clarity

plt.bar([2012.6, 2013.6], mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")

# if you don't do this, matplotlib will label the x-axis 0, 1
# and then add a +2.013e3 off in the corner (bad matplotlib!)
plt.ticklabel_format(useOffset=False)

plt.axis([2012.5,2014.5,0,550])
plt.title("Not So Huge Anymore.")

# %% [markdown]
# # Line charts

# %%
variance     = [1,2,4,8,16,32,64,128,256]
bias_squared = [256,128,64,32,16,8,4,2,1]
total_error  = [x + y for x, y in zip(variance, bias_squared)]

xs = range(len(variance))

# we can make multiple calls to plt.plot 
# to show multiple series on the same chart
plt.plot(xs, variance,     'g-',  label='variance')    # green solid line
plt.plot(xs, bias_squared, 'r-.', label='bias^2')      # red dot-dashed line
plt.plot(xs, total_error,  'b:',  label='total error') # blue dotted line

# because we've assigned labels to each series
# we can get a legend for free
# loc=9 means "top center"
plt.legend(loc=9)
plt.xlabel("model complexity")
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %% [markdown]
# # Scatterplots

# %%
friends = [ 70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

# label each point
for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label, # the label to use
             xy=(friend_count, minute_count), # put the label with its point
             xytext=(5, -5), # but slightly offset
             textcoords='offset points')

plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site")
plt.show()

# %%
# be careful when letting matplotlib choose axes

test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")

plt.show()

# %%
# add a call to plt.axis('equal')

test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")

plt.axis('equal')

plt.show()
